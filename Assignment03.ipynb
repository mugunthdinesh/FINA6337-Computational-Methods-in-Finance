# %% [markdown]
# ### Assignment 3
# ###### Submission by Mugunth Dhinesh Kumar and Rahul Krishnani

# %%
# Place all your imports here
import yfinance as yf
import pandas_datareader.data as web
import numpy as np
import statsmodels.api as sm
import pandas as pd
from statsmodels.tsa.ar_model import AutoReg

# %% [markdown]
# This exercise involves estimating CAPM on: Gold, Exxon, General Electric, IBM, Microsoft, and Walmart. After downloading the price data (for these assets and also for the S&P 500 index and the 4-week treasury bill), you'll conduct the following steps:
# - Calculate the monthly returns for each.
# - Letting $r_{it}-r_{ft}$ represent the excess return on asset $i$ and $r_{mt}-r_{ft}$ represent the excess return on the market (proxied by the S&P 500), estimate: $r_{it}-r_{ft} = \alpha + \beta(r_{mt}-r_{ft}) + u_t$.
# - For each asset test the restrictions $\alpha = 0$ and $\beta = 0$ both individually and jointly.

# %%
# This step takes care of downloading the prices
# Adjusted stock prices from Yahoo! Finance
data = yf.download('^GSPC XOM GE IBM MSFT WMT GC=F', start='2005-01-01', end='2020-01-31', interval='1mo')['Adj Close']
# 4-week Treasury Bill rate from FRED
tbill = web.DataReader(['TB4WK'], 'fred', start='2005-01-01', end='2019-12-31')
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %% [markdown]
# Create a new dataframe called *ret* that contains the continuous compounded monthly return for each asset in *data*. This should only take one line.

# %%
# Your code here
ret=np.log(data).diff()

# %% [markdown]
# If you take a look at *ret*, you'll notice that the first row is NaN and the first return is for Feb 2005. This is expected since the first return will be based on the prices in the first two rows. However, since the prices are for the beginning of each month, it means that the first return should really be for Jan 2005. Fix this. After you're done, what was previously the return for Feb 2005 should be now assigned to Jan 2005 and so on for all the remaining months.

# %%
# Your code here
ret=ret.shift(-1, axis=0)

# %% [markdown]
# Next, let's get to the *tbill* data. Treasury bills are quoted on a 360-day discount basis. We have the 4-week Treasury Bill rate and the rate is quoted on an annualized basis. To convert into the 4-week rate (which is what we need since all our data are monthly), scale the quoted rate by multiplying by 4/52 (or 1/13). The other adjustment to make is that the quote is in percentage while our other returns data is in decimal format. So you'll need to fix this too. After fixing the Treasury rate, join that series with the *ret* dataframe. All of this can be done in one step.

# %%
# Your code here
ret["TBILL"]=(tbill*4/52/100)

# %% [markdown]
# Now you're ready to estimate CAPM for each of the six assets (don't forget to add the constant for each). There are three steps for each of them:
# 1. Estimate the model (you can use OLS from statsmodels for this) and print out the summary.
# 2. Test the restriction $\alpha = 0$ and $\beta = 1$ **individually**.
# 3. Test the restriction $\alpha = 0$ and $\beta = 1$ **jointly**.
# The three code cells below are for Exxon. Follow the same pattern for: GE, IBM, Microsoft, Walmart, Gold. At the end, insert a new Markdown cell and discuss how the $\beta$ for Gold differs from the rest and what it means.
#
# **Important note**: All the returns data have a missing value at the bottom. In addition, the gold data from Yahoo! Finance also has additional missing observations. Don't delete any of these manually. Instead, you can take care of this by using an argument inside the OLS function. Look up the documentation here: https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.OLS.html#statsmodels.regression.linear_model.OLS

# %%
# Estimating the model for all the assets

# Iterating over coloumns in ret
for stock in ret.columns:
    # Skip TBILL and ^GSPC column
    if stock == 'TBILL':
        continue
    if stock == '^GSPC':
        continue    
    
    # setting up data for OLS regression 
    y = ret[stock] - ret['TBILL']
    x = ret['^GSPC'] - ret['TBILL']
    x = sm.add_constant(x)
    
    # Fit the model
    model = sm.OLS(y, x, missing='drop').fit()
    
    # Print results
    print(f"{stock} Results")
    print(model.summary())
    print("\n" * 3)
# Out:
# GC=F Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.6646
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):              0.416
# Time:                        21:59:17   Log-Likelihood:                 196.35
# No. Observations:                 128   AIC:                            -388.7
# Df Residuals:                     126   BIC:                            -383.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0068      0.005      1.458      0.147      -0.002       0.016
# 0              0.0923      0.113      0.815      0.416      -0.132       0.317
# ==============================================================================
# Omnibus:                        6.664   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                6.861
# Skew:                          -0.392   Prob(JB):                       0.0324
# Kurtosis:                       3.820   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# GE Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     142.4
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):           1.71e-24
# Time:                        21:59:17   Log-Likelihood:                 239.12
# No. Observations:                 180   AIC:                            -474.2
# Df Residuals:                     178   BIC:                            -467.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0099      0.005     -2.042      0.043      -0.019      -0.000
# 0              1.4234      0.119     11.933      0.000       1.188       1.659
# ==============================================================================
# Omnibus:                       40.149   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.353
# Skew:                          -0.840   Prob(JB):                     3.00e-29
# Kurtosis:                       6.833   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# IBM Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     92.32
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):           7.17e-18
# Time:                        21:59:17   Log-Likelihood:                 289.05
# No. Observations:                 180   AIC:                            -574.1
# Df Residuals:                     178   BIC:                            -567.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.004     -0.146      0.884      -0.008       0.007
# 0              0.8685      0.090      9.608      0.000       0.690       1.047
# ==============================================================================
# Omnibus:                       21.067   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.212
# Skew:                          -0.447   Prob(JB):                     1.69e-12
# Kurtosis:                       5.535   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# MSFT Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     121.0
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):           8.35e-22
# Time:                        21:59:17   Log-Likelihood:                 282.83
# No. Observations:                 180   AIC:                            -561.7
# Df Residuals:                     178   BIC:                            -555.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0064      0.004      1.699      0.091      -0.001       0.014
# 0              1.0293      0.094     11.000      0.000       0.845       1.214
# ==============================================================================
# Omnibus:                       11.334   Durbin-Watson:                   2.336
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               23.817
# Skew:                           0.197   Prob(JB):                     6.73e-06
# Kurtosis:                       4.738   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# WMT Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     16.20
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):           8.42e-05
# Time:                        21:59:17   Log-Likelihood:                 298.77
# No. Observations:                 180   AIC:                            -593.5
# Df Residuals:                     178   BIC:                            -587.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0036      0.003      1.050      0.295      -0.003       0.010
# 0              0.3447      0.086      4.025      0.000       0.176       0.514
# ==============================================================================
# Omnibus:                        8.544   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               14.067
# Skew:                          -0.202   Prob(JB):                     0.000882
# Kurtosis:                       4.308   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# XOM Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.284
# Method:                 Least Squares   F-statistic:                     71.93
# Date:                Fri, 05 Apr 2024   Prob (F-statistic):           8.36e-15
# Time:                        21:59:17   Log-Likelihood:                 303.59
# No. Observations:                 180   AIC:                            -603.2
# Df Residuals:                     178   BIC:                            -596.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.003     -0.253      0.801      -0.008       0.006
# 0              0.7071      0.083      8.481      0.000       0.543       0.872
# ==============================================================================
# Omnibus:                       11.439   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               20.094
# Skew:                           0.297   Prob(JB):                     4.33e-05
# Kurtosis:                       4.525   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Test the individual restrictions for Exxon

# %% [markdown]
# Test for  $\alpha $ :
# - H0: $\alpha = 0$
# - H1: $\alpha ≠ 0$
#
# Test for $\beta $ :
# - H0: $\alpha = 1$
# - H1: $\alpha ≠ 1$

# %%
# Test the joint restriction for Exxon

# %% [markdown]
# Test for $\alpha $ & $\beta $:
# - H0: $\alpha $ = 0 & $\beta $ = 1
# - H1: $\alpha $ ≠ 0 & $\beta $ ≠ 1

# %%
# Iterate over columns in ret
for stock in ret.columns:
    # Skip TBILL and ^GSPC columns
    if stock in ['TBILL', '^GSPC']:
        continue
    
    # setting up data for OLS regression 
    y = ret[stock] - ret['TBILL']
    x = ret['^GSPC'] - ret['TBILL']
    x = sm.add_constant(x)
    
    # Fitting the model
    model = sm.OLS(y, x, missing='drop').fit()
    
    # Performing individual t-tests on the intercept and slope terms
    t_test_results_intercept = model.t_test([1, 0])
    t_test_results_slope = model.t_test([0, 1])
    
    # Performing F-test on the joint significance of intercept and slope
    f_test_results_joint = model.f_test([[1, 0], [0, 1]])
    
    # Print results
    print(f"{stock} T-Test Results for Intercept")
    print(t_test_results_intercept)
    print(f"{stock} T-Test Results for Slope")
    print(t_test_results_slope)
    print(f"{stock} F-Test Results for Joint Significance")
    print(f_test_results_joint)
    print("\n" * 4)
# Out:
# GC=F T-Test Results for Intercept
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0068      0.005      1.458      0.147      -0.002       0.016
# ==============================================================================
# GC=F T-Test Results for Slope
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0923      0.113      0.815      0.416      -0.132       0.317
# ==============================================================================
# GC=F F-Test Results for Joint Significance
# <F test: F=1.4639277730642495, p=0.23523314672277182, df_denom=126, df_num=2>
#
#
#
#
#
# GE T-Test Results for Intercept
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0099      0.005     -2.042      0.043      -0.019      -0.000
# ==============================================================================
# GE T-Test Results for Slope
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             1.4234      0.119     11.933      0.000       1.188       1.659
# ==============================================================================
# GE F-Test Results for Joint Significance
# <F test: F=71.4266722638749, p=1.6830437897112248e-23, df_denom=178, df_num=2>
#
#
#
#
#
# IBM T-Test Results for Intercept
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0005      0.004     -0.146      0.884      -0.008       0.007
# ==============================================================================
# IBM T-Test Results for Slope
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.8685      0.090      9.608      0.000       0.690       1.047
# ==============================================================================
# IBM F-Test Results for Joint Significance
# <F test: F=46.616387079603804, p=5.2471978184596543e-17, df_denom=178, df_num=2>
#
#
#
#
#
# MSFT T-Test Results for Intercept
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0064      0.004      1.699      0.091      -0.001       0.014
# ==============================================================================
# MSFT T-Test Results for Slope
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             1.0293      0.094     11.000      0.000       0.845       1.214
# ==============================================================================
# MSFT F-Test Results for Joint Significance
# <F test: F=64.92428557799266, p=6.689205671995083e-22, df_denom=178, df_num=2>
#
#
#
#
#
# WMT T-Test Results for Intercept
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0036      0.003      1.050      0.295      -0.003       0.010
# ==============================================================================
# WMT T-Test Results for Slope
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.3447      0.086      4.025      0.000       0.176       0.514
# ==============================================================================
# WMT F-Test Results for Joint Significance
# <F test: F=9.254325761644026, p=0.00015011050637837162, df_denom=178, df_num=2>
#
#
#
#
#
# XOM T-Test Results for Intercept
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0009      0.003     -0.253      0.801      -0.008       0.006
# ==============================================================================
# XOM T-Test Results for Slope
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.7071      0.083      8.481      0.000       0.543       0.872
# ==============================================================================
# XOM F-Test Results for Joint Significance
# <F test: F=36.22531922629283, p=6.325712743242226e-14, df_denom=178, df_num=2>

# %% [markdown]
# #### Discussion- Gold's $\beta$
# Gold has a $\beta$ co-efficient of 0.09. The individual and joint hypothesis tests reveal a t-stat of 0.815 and f-stat of 1.463. The corresponding p values are 0.416 and 0.235 respectively which are not significant even at the 1% level. This indicates that Gold's returns are not significantly related to the returns of the market index. Further, this could imply that gold is not subject to the same systematic risk factors as the market.

# %% [markdown]
# #### AR Model Fitting
#
# For each of the 6 assets, estimate an AR(1) model. From the results of the estimation, create a markdown cell and comment on if the first-order autocorrelation is statistically significant.

# %%
# Estimate AR(1) for Exxon
assets = ['GC=F', 'GE', 'IBM', 'MSFT', 'WMT','XOM']
for asset in assets:
    ar1_model = AutoReg(ret[asset], lags=1, missing='drop').fit()
    print(f"Results for {asset}:")
    print(ar1_model.summary())
    print("\n" * 2)
# Out:
# Results for GC=F:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   GC=F   No. Observations:                  128
# Model:                     AutoReg(1)   Log Likelihood                 194.039
# Method:               Conditional MLE   S.D. of innovations              0.053
# Date:                Fri, 05 Apr 2024   AIC                           -382.078
# Time:                        21:59:18   BIC                           -373.545
# Sample:                             1   HQIC                          -378.611
#                                   128
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0082      0.005      1.736      0.082      -0.001       0.017
# GC=F.L1       -0.0539      0.089     -0.608      0.543      -0.228       0.120
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -18.5359           +0.0000j           18.5359            0.5000
# -----------------------------------------------------------------------------
#
#
#
# Results for GE:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                     GE   No. Observations:                  180
# Model:                     AutoReg(1)   Log Likelihood                 186.148
# Method:               Conditional MLE   S.D. of innovations              0.086
# Date:                Fri, 05 Apr 2024   AIC                           -366.295
# Time:                        21:59:18   BIC                           -356.733
# Sample:                    02-01-2005   HQIC                          -362.418
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0018      0.006     -0.287      0.774      -0.014       0.011
# GE.L1          0.1243      0.075      1.668      0.095      -0.022       0.270
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            8.0468           +0.0000j            8.0468            0.0000
# -----------------------------------------------------------------------------
#
#
#
# Results for IBM:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    IBM   No. Observations:                  180
# Model:                     AutoReg(1)   Log Likelihood                 250.159
# Method:               Conditional MLE   S.D. of innovations              0.060
# Date:                Fri, 05 Apr 2024   AIC                           -494.319
# Time:                        21:59:18   BIC                           -484.757
# Sample:                    02-01-2005   HQIC                          -490.441
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0049      0.004      1.084      0.279      -0.004       0.014
# IBM.L1        -0.0840      0.075     -1.125      0.261      -0.230       0.062
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -11.8997           +0.0000j           11.8997            0.5000
# -----------------------------------------------------------------------------
#
#
#
# Results for MSFT:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   MSFT   No. Observations:                  180
# Model:                     AutoReg(1)   Log Likelihood                 234.977
# Method:               Conditional MLE   S.D. of innovations              0.065
# Date:                Fri, 05 Apr 2024   AIC                           -463.953
# Time:                        21:59:18   BIC                           -454.391
# Sample:                    02-01-2005   HQIC                          -460.076
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0130      0.005      2.624      0.009       0.003       0.023
# MSFT.L1       -0.0428      0.075     -0.573      0.567      -0.189       0.104
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -23.3543           +0.0000j           23.3543            0.5000
# -----------------------------------------------------------------------------
#
#
#
# Results for WMT:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    WMT   No. Observations:                  180
# Model:                     AutoReg(1)   Log Likelihood                 289.182
# Method:               Conditional MLE   S.D. of innovations              0.048
# Date:                Fri, 05 Apr 2024   AIC                           -572.364
# Time:                        21:59:18   BIC                           -562.801
# Sample:                    02-01-2005   HQIC                          -568.486
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0066      0.004      1.815      0.069      -0.001       0.014
# WMT.L1        -0.0425      0.075     -0.568      0.570      -0.189       0.104
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -23.5383           +0.0000j           23.5383            0.5000
# -----------------------------------------------------------------------------
#
#
#
# Results for XOM:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    XOM   No. Observations:                  180
# Model:                     AutoReg(1)   Log Likelihood                 279.659
# Method:               Conditional MLE   S.D. of innovations              0.051
# Date:                Fri, 05 Apr 2024   AIC                           -553.317
# Time:                        21:59:18   BIC                           -543.755
# Sample:                    02-01-2005   HQIC                          -549.440
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.004      0.722      0.471      -0.005       0.010
# XOM.L1        -0.1229      0.072     -1.703      0.089      -0.264       0.019
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -8.1386           +0.0000j            8.1386            0.5000
# -----------------------------------------------------------------------------
# /Users/mugunth/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Discussion: First order Auto-correlation of Assets
# The first-order autocorrelation coefficients for all assets (Gold, GE, IBM, MSFT, WMT, and XOM) in the autoregressive (AR) models are not statistically significant, with p-values ranging from 0.089 to 0.570. This indicates that there is no significant linear relationship between the current period's return and the return from the previous period for any of the assets. This means the past returns do not significantly predict future returns for these assets based on their AR models. Hence, there is no evidence to suggest significant autocorrelation in the returns of these assets at the first order lag.

# %% [markdown]
# Now, for each of the 6 assets, estimate an AR(2) model. Then, for each asset, comment on if this is a better fit compared to the AR(1) model. Explain why.

# %%
# Estimate AR(2) for Exxon
assets = ['GC=F', 'GE', 'IBM', 'MSFT', 'WMT', 'XOM']
for asset in assets:
    ar2_model = AutoReg(ret[asset], lags=2, missing='drop').fit()
    print(f"Results for {asset}:")
    print(ar2_model.summary())
    print("\n" * 2)
# Out:
# Results for GC=F:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   GC=F   No. Observations:                  128
# Model:                     AutoReg(2)   Log Likelihood                 192.830
# Method:               Conditional MLE   S.D. of innovations              0.052
# Date:                Fri, 05 Apr 2024   AIC                           -377.659
# Time:                        21:59:18   BIC                           -366.314
# Sample:                             2   HQIC                          -373.050
#                                   128
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0075      0.005      1.570      0.117      -0.002       0.017
# GC=F.L1       -0.0470      0.089     -0.530      0.596      -0.221       0.127
# GC=F.L2        0.1062      0.089      1.194      0.233      -0.068       0.281
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.8548           +0.0000j            2.8548            0.5000
# AR.2            3.2976           +0.0000j            3.2976            0.0000
# -----------------------------------------------------------------------------
#
#
#
# Results for GE:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                     GE   No. Observations:                  180
# Model:                     AutoReg(2)   Log Likelihood                 185.162
# Method:               Conditional MLE   S.D. of innovations              0.086
# Date:                Fri, 05 Apr 2024   AIC                           -362.323
# Time:                        21:59:18   BIC                           -349.596
# Sample:                    03-01-2005   HQIC                          -357.162
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0022      0.006     -0.347      0.729      -0.015       0.010
# GE.L1          0.1339      0.075      1.783      0.075      -0.013       0.281
# GE.L2         -0.0720      0.075     -0.959      0.338      -0.219       0.075
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.9300           -3.6089j            3.7268           -0.2099
# AR.2            0.9300           +3.6089j            3.7268            0.2099
# -----------------------------------------------------------------------------
#
#
#
# Results for IBM:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    IBM   No. Observations:                  180
# Model:                     AutoReg(2)   Log Likelihood                 248.871
# Method:               Conditional MLE   S.D. of innovations              0.060
# Date:                Fri, 05 Apr 2024   AIC                           -489.742
# Time:                        21:59:18   BIC                           -477.014
# Sample:                    03-01-2005   HQIC                          -484.580
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0046      0.005      1.021      0.307      -0.004       0.013
# IBM.L1        -0.0776      0.075     -1.036      0.300      -0.225       0.069
# IBM.L2         0.0800      0.075      1.068      0.286      -0.067       0.227
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.0832           +0.0000j            3.0832            0.5000
# AR.2            4.0531           +0.0000j            4.0531            0.0000
# -----------------------------------------------------------------------------
#
#
#
# Results for MSFT:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   MSFT   No. Observations:                  180
# Model:                     AutoReg(2)   Log Likelihood                 233.634
# Method:               Conditional MLE   S.D. of innovations              0.065
# Date:                Fri, 05 Apr 2024   AIC                           -459.267
# Time:                        21:59:18   BIC                           -446.540
# Sample:                    03-01-2005   HQIC                          -454.106
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0128      0.005      2.540      0.011       0.003       0.023
# MSFT.L1       -0.0448      0.075     -0.597      0.550      -0.192       0.102
# MSFT.L2        0.0409      0.075      0.546      0.585      -0.106       0.188
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -4.4292           +0.0000j            4.4292            0.5000
# AR.2            5.5247           +0.0000j            5.5247            0.0000
# -----------------------------------------------------------------------------
#
#
#
# Results for WMT:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    WMT   No. Observations:                  180
# Model:                     AutoReg(2)   Log Likelihood                 287.526
# Method:               Conditional MLE   S.D. of innovations              0.048
# Date:                Fri, 05 Apr 2024   AIC                           -567.051
# Time:                        21:59:18   BIC                           -554.324
# Sample:                    03-01-2005   HQIC                          -561.890
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0071      0.004      1.931      0.054      -0.000       0.014
# WMT.L1        -0.0463      0.075     -0.618      0.537      -0.193       0.101
# WMT.L2        -0.0431      0.075     -0.576      0.565      -0.190       0.104
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.5366           -4.7853j            4.8153           -0.2678
# AR.2           -0.5366           +4.7853j            4.8153            0.2678
# -----------------------------------------------------------------------------
#
#
#
# Results for XOM:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    XOM   No. Observations:                  180
# Model:                     AutoReg(2)   Log Likelihood                 278.074
# Method:               Conditional MLE   S.D. of innovations              0.051
# Date:                Fri, 05 Apr 2024   AIC                           -548.147
# Time:                        21:59:18   BIC                           -535.420
# Sample:                    03-01-2005   HQIC                          -542.986
#                          - 12-01-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.004      0.812      0.417      -0.004       0.011
# XOM.L1        -0.1145      0.076     -1.510      0.131      -0.263       0.034
# XOM.L2        -0.0508      0.073     -0.698      0.485      -0.193       0.092
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1270           -4.2905j            4.4360           -0.2909
# AR.2           -1.1270           +4.2905j            4.4360            0.2909
# -----------------------------------------------------------------------------
# /Users/mugunth/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Discussion - AR(2) vs AR(1) model
# In the AR1 models, both gold, the GSPC index, and all the stocks exhibit lower AIC, BIC, and HQIC values compared to the AR2 models:
#
# - ⁠Fit: better model fit:
# - Complexity: AR1 has better balance between good fit and simplicity than AR2 model
# - Interpretability: AR1 is a more suitable choice for time-series analysis
# - Characteristics: stronger correlation at lag 1 than at 2 lags
